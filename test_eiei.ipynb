# %% [markdown]
# <a href="https://colab.research.google.com/github/Satayu13246/test-colab/blob/main/test_eiei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
print('world')
# Out:
# world

# %%
c = 15
v = 2
print(c-v)
# Out:
# 13

# %%
print('อะไรวะ')
# Out:
# อะไรวะ

# %%
print('ได้ละ')
# Out:
# ได้ละ

# %%
print('อิอิ')
# Out:
# อิอิ

# %%
print('ควย')
# Out:
# ควย

# %%
print('เข้าใกล้ความเป็นจริง')
# Out:
# เข้าใกล้ความเป็นจริง

# %%
print('ได้ละ')
# Out:
# ได้ละ

# %%
print('สุดท้าย')
# Out:
# สุดท้าย
